# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=1_ZoJOp39dxsRTVndJP1_7jdY7oGi8sSu)
#
# <h1><center>Redes Neuronales con Keras y Scikit</center></h1>
#
#
# <center><i>Creando nuestra primera red neuronal</i></center>

# %% [markdown]
# # <h1>Contenido</h1>
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#     <ol>
#         <li><a href="#problema">Contexto Analítico</a></li>
#         <li><a href="#arquitectura">Arquitectura propuesta</a></li>
#         <li><a href="#keras">Entrenamiento y Evaluación del Modelo</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# # <h1 id="problema">Contexto analítico</h1>
#
# Requerimos diseñar un modelo que permita determinar el precio medio de las viviendas en Boston, para ello contamos con un set de información disponible en Keras con características y precios de viviendas en diferentes ubicaciones de Boston de finales de 1970. (Mayor detalle disponible en http://lib.stat.cmu.edu/datasets/boston
#
# En total contamos con 506 muestras caracterizadas por 13 variables.

# %% [markdown]
#  Variables | Description
#  --- | ---
#  CRIM   |  per capita crime rate by town
#  ZN     |  proportion of residential land zoned for lots over 25,000 sq.ft.
#  INDUS  |  proportion of non-retail business acres per town
#  CHAS   |  Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  NOX    |  nitric oxides concentration (parts per 10 million)
#  RM     |  average number of rooms per dwelling
#  AGE    |  proportion of owner-occupied units built prior to 1940
#  DIS    |  weighted distances to five Boston employment centres
#  RAD    |  index of accessibility to radial highways
#  TAX    |  full-value property-tax rate per \$10,000
#  PTRATIO|  pupil-teacher ratio by town
#  B      |  1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT  |  % lower status of the population
#  MEDV   |  Median value of owner-occupied homes in $1000's

# %%
from keras.datasets import boston_housing
(x_train, y_train), (x_test, y_test) = boston_housing.load_data(test_split=0.2,seed=10)

# %%
print("Tamaño set de entrenamiento:",x_train.shape)
print("Tamaño set de prueba:",x_test.shape)
# Out:
# Tamaño set de entrenamiento: (404, 13)
# Tamaño set de prueba: (102, 13)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (404,)
# (102,)

# %%
x_train[:1]
# Out:
# array([[5.4790e-02, 3.3000e+01, 2.1800e+00, 0.0000e+00, 4.7200e-01,
#         6.6160e+00, 5.8100e+01, 3.3700e+00, 7.0000e+00, 2.2200e+02,
#         1.8400e+01, 3.9336e+02, 8.9300e+00]])

# %% [markdown]
# # <h1 id="arquitectura">Arquitectura propuesta de Red Neuronal</h1>
#
# Para diseñar el modelo implementaremos un red tal y como se ilustra enseguida:
#
# ![Arquitectura1](https://drive.google.com/uc?id=1RndIWQ4yVr9AvWi6Zbn6QNRpAJf33VeV)

# %%
import numpy as np
from keras.models import Sequential      #Nos permiten establecer las capas neuronales que se van a utilizar
from keras.layers import Dense, Activation     #Dense (Capa Densa, esta conectada a la sig capa 

#Definición de la arquitectura
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal',activation='relu'))    #13 variables de entrada 
model.add(Dense(6, kernel_initializer='normal',activation='relu'))
model.add(Dense(4, kernel_initializer='normal',activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))

# Compilación del modelo
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mean_absolute_percentage_error'])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 13)                182
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 84
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 299
# Trainable params: 299
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png',show_shapes=True)

# %% [markdown]
# # <h1 id="keras">Entrenamiento y Evaluación del modelo</h1>
#
# Ahora realizaremos diferentes entrenamientos de la red neuronal diseña y evaluaremos su desempeño.

# %%
#Entrena el modelo   (Este primer intento de validacion nos arroja un error muy alto de casi el 99 %)
x_val = x_train[300:,]    #Datos Validacion 
y_val = y_train[300:,]
#Entrena el modelo
model.fit(x_train, y_train, batch_size=32, epochs=5,validation_data=(x_val,y_val))   #Batch_size muestras que va a ir suministrando, epochs cantidad de iteraciones del alg
# Out:
# Train on 404 samples, validate on 104 samples
# Epoch 1/5
# 404/404 [==============================] - 0s 1ms/step - loss: 589.2344 - mean_absolute_percentage_error: 99.8271 - val_loss: 533.7712 - val_mean_absolute_percentage_error: 99.5398
# Epoch 2/5
# 404/404 [==============================] - 0s 62us/step - loss: 582.4459 - mean_absolute_percentage_error: 98.9972 - val_loss: 521.4690 - val_mean_absolute_percentage_error: 97.8499
# Epoch 3/5
# 404/404 [==============================] - 0s 62us/step - loss: 558.5509 - mean_absolute_percentage_error: 95.9343 - val_loss: 481.2139 - val_mean_absolute_percentage_error: 92.0814
# Epoch 4/5
# 404/404 [==============================] - 0s 69us/step - loss: 491.1486 - mean_absolute_percentage_error: 86.3397 - val_loss: 378.4933 - val_mean_absolute_percentage_error: 76.0031
# Epoch 5/5
# 404/404 [==============================] - 0s 69us/step - loss: 342.6780 - mean_absolute_percentage_error: 64.9197 - val_loss: 206.1876 - val_mean_absolute_percentage_error: 48.8280

# %%
results = model.evaluate(x_test, y_test)

for i in range(len(model.metrics_names)):
  print(model.metrics_names[i]," : ", results[i])
# Out:
# 102/102 [==============================] - 0s 59us/step
# loss  :  222.73087265912224
# mean_absolute_percentage_error  :  46.856502532958984

# %%
model.fit(x_train, y_train, batch_size=32, epochs=100,validation_data=(x_val,y_val))    #Con 100 iteraciones se tiene un % de error mucho menor 13%
# Out:
# Train on 404 samples, validate on 104 samples
# Epoch 1/100
# 404/404 [==============================] - 0s 109us/step - loss: 167.6342 - mean_absolute_percentage_error: 44.2309 - val_loss: 120.9676 - val_mean_absolute_percentage_error: 49.1061
# Epoch 2/100
# 404/404 [==============================] - 0s 74us/step - loss: 137.3014 - mean_absolute_percentage_error: 53.7465 - val_loss: 125.6537 - val_mean_absolute_percentage_error: 53.2886
# Epoch 3/100
# 404/404 [==============================] - 0s 69us/step - loss: 127.4459 - mean_absolute_percentage_error: 45.9731 - val_loss: 109.4647 - val_mean_absolute_percentage_error: 41.5753
# Epoch 4/100
# 404/404 [==============================] - 0s 62us/step - loss: 117.6297 - mean_absolute_percentage_error: 42.3652 - val_loss: 105.0421 - val_mean_absolute_percentage_error: 43.5103
# Epoch 5/100
# 404/404 [==============================] - 0s 64us/step - loss: 110.9645 - mean_absolute_percentage_error: 42.4316 - val_loss: 101.1987 - val_mean_absolute_percentage_error: 42.7770
# Epoch 6/100
# 404/404 [==============================] - 0s 64us/step - loss: 106.7489 - mean_absolute_percentage_error: 41.9489 - val_loss: 97.5809 - val_mean_absolute_percentage_error: 42.1338
# Epoch 7/100
# 404/404 [==============================] - 0s 92us/step - loss: 102.0979 - mean_absolute_percentage_error: 39.4627 - val_loss: 92.5751 - val_mean_absolute_percentage_error: 38.9213
# Epoch 8/100
# 404/404 [==============================] - 0s 64us/step - loss: 97.7672 - mean_absolute_percentage_error: 38.2563 - val_loss: 90.0022 - val_mean_absolute_percentage_error: 39.8431
# Epoch 9/100
# 404/404 [==============================] - 0s 64us/step - loss: 94.3712 - mean_absolute_percentage_error: 37.9153 - val_loss: 86.5825 - val_mean_absolute_percentage_error: 38.9830
# Epoch 10/100
# 404/404 [==============================] - 0s 84us/step - loss: 91.0664 - mean_absolute_percentage_error: 37.9773 - val_loss: 84.3116 - val_mean_absolute_percentage_error: 39.2354
# Epoch 11/100
# 404/404 [==============================] - 0s 79us/step - loss: 87.3811 - mean_absolute_percentage_error: 36.7961 - val_loss: 81.7117 - val_mean_absolute_percentage_error: 38.2866
# Epoch 12/100
# 404/404 [==============================] - 0s 136us/step - loss: 84.9734 - mean_absolute_percentage_error: 35.4339 - val_loss: 79.4360 - val_mean_absolute_percentage_error: 37.5571
# Epoch 13/100
# 404/404 [==============================] - 0s 111us/step - loss: 82.4685 - mean_absolute_percentage_error: 34.5847 - val_loss: 77.9221 - val_mean_absolute_percentage_error: 37.5439
# Epoch 14/100
# 404/404 [==============================] - 0s 111us/step - loss: 80.3712 - mean_absolute_percentage_error: 34.9462 - val_loss: 76.5506 - val_mean_absolute_percentage_error: 37.6699
# Epoch 15/100
# 404/404 [==============================] - 0s 136us/step - loss: 78.4314 - mean_absolute_percentage_error: 34.4841 - val_loss: 75.5496 - val_mean_absolute_percentage_error: 37.7724
# Epoch 16/100
# 404/404 [==============================] - 0s 144us/step - loss: 77.2487 - mean_absolute_percentage_error: 33.8688 - val_loss: 74.3913 - val_mean_absolute_percentage_error: 37.5183
# Epoch 17/100
# 404/404 [==============================] - 0s 121us/step - loss: 75.6372 - mean_absolute_percentage_error: 34.2068 - val_loss: 73.7282 - val_mean_absolute_percentage_error: 37.6761
# Epoch 18/100
# 404/404 [==============================] - 0s 87us/step - loss: 74.4869 - mean_absolute_percentage_error: 34.1879 - val_loss: 72.1919 - val_mean_absolute_percentage_error: 36.3547
# Epoch 19/100
# 404/404 [==============================] - 0s 89us/step - loss: 73.4237 - mean_absolute_percentage_error: 32.3107 - val_loss: 71.3420 - val_mean_absolute_percentage_error: 36.1715
# Epoch 20/100
# 404/404 [==============================] - 0s 92us/step - loss: 72.3334 - mean_absolute_percentage_error: 32.3085 - val_loss: 70.3707 - val_mean_absolute_percentage_error: 35.7798
# Epoch 21/100
# 404/404 [==============================] - 0s 109us/step - loss: 71.0021 - mean_absolute_percentage_error: 32.5536 - val_loss: 70.3439 - val_mean_absolute_percentage_error: 37.1266
# Epoch 22/100
# 404/404 [==============================] - 0s 82us/step - loss: 70.0108 - mean_absolute_percentage_error: 32.5257 - val_loss: 68.7161 - val_mean_absolute_percentage_error: 35.2944
# Epoch 23/100
# 404/404 [==============================] - 0s 94us/step - loss: 69.1271 - mean_absolute_percentage_error: 31.5897 - val_loss: 68.1762 - val_mean_absolute_percentage_error: 35.6884
# Epoch 24/100
# 404/404 [==============================] - 0s 52us/step - loss: 68.5594 - mean_absolute_percentage_error: 31.2309 - val_loss: 67.2421 - val_mean_absolute_percentage_error: 35.3360
# Epoch 25/100
# 404/404 [==============================] - 0s 64us/step - loss: 67.4326 - mean_absolute_percentage_error: 31.4580 - val_loss: 66.3899 - val_mean_absolute_percentage_error: 34.7672
# Epoch 26/100
# 404/404 [==============================] - 0s 57us/step - loss: 67.2716 - mean_absolute_percentage_error: 30.3723 - val_loss: 65.9321 - val_mean_absolute_percentage_error: 35.0297
# Epoch 27/100
# 404/404 [==============================] - 0s 67us/step - loss: 66.0878 - mean_absolute_percentage_error: 30.6066 - val_loss: 64.9185 - val_mean_absolute_percentage_error: 34.1637
# Epoch 28/100
#  32/404 [=>............................] - ETA: 0s - loss: 75.4801 - mean_absolute_percentage_error: 42.19404/404 [==============================] - 0s 67us/step - loss: 65.5204 - mean_absolute_percentage_error: 30.2664 - val_loss: 64.4983 - val_mean_absolute_percentage_error: 34.4211
# Epoch 29/100
# 404/404 [==============================] - 0s 67us/step - loss: 65.0577 - mean_absolute_percentage_error: 29.5095 - val_loss: 63.9186 - val_mean_absolute_percentage_error: 34.2775
# Epoch 30/100
# 404/404 [==============================] - 0s 59us/step - loss: 64.0819 - mean_absolute_percentage_error: 29.8005 - val_loss: 62.9418 - val_mean_absolute_percentage_error: 33.4396
# Epoch 31/100
# 404/404 [==============================] - 0s 62us/step - loss: 63.7119 - mean_absolute_percentage_error: 29.6393 - val_loss: 62.6497 - val_mean_absolute_percentage_error: 33.7815
# Epoch 32/100
# 404/404 [==============================] - 0s 59us/step - loss: 63.0467 - mean_absolute_percentage_error: 28.6045 - val_loss: 61.5129 - val_mean_absolute_percentage_error: 32.4112
# Epoch 33/100
# 404/404 [==============================] - 0s 59us/step - loss: 62.3385 - mean_absolute_percentage_error: 28.4935 - val_loss: 61.6577 - val_mean_absolute_percentage_error: 33.4488
# Epoch 34/100
# 404/404 [==============================] - 0s 62us/step - loss: 62.4849 - mean_absolute_percentage_error: 28.7459 - val_loss: 60.6499 - val_mean_absolute_percentage_error: 32.5163
# Epoch 35/100
# 404/404 [==============================] - 0s 64us/step - loss: 61.7357 - mean_absolute_percentage_error: 28.7361 - val_loss: 60.1964 - val_mean_absolute_percentage_error: 32.3866
# Epoch 36/100
# 404/404 [==============================] - 0s 74us/step - loss: 61.2510 - mean_absolute_percentage_error: 27.5113 - val_loss: 59.7360 - val_mean_absolute_percentage_error: 32.1818
# Epoch 37/100
# 404/404 [==============================] - 0s 62us/step - loss: 60.7044 - mean_absolute_percentage_error: 27.8616 - val_loss: 59.0982 - val_mean_absolute_percentage_error: 31.7064
# Epoch 38/100
# 404/404 [==============================] - 0s 59us/step - loss: 60.2240 - mean_absolute_percentage_error: 27.7160 - val_loss: 58.8103 - val_mean_absolute_percentage_error: 31.7977
# Epoch 39/100
# 404/404 [==============================] - 0s 64us/step - loss: 59.7488 - mean_absolute_percentage_error: 27.5497 - val_loss: 58.2528 - val_mean_absolute_percentage_error: 31.4799
# Epoch 40/100
# 404/404 [==============================] - 0s 72us/step - loss: 59.5781 - mean_absolute_percentage_error: 26.3151 - val_loss: 57.4908 - val_mean_absolute_percentage_error: 30.4707
# Epoch 41/100
# 404/404 [==============================] - 0s 67us/step - loss: 59.1536 - mean_absolute_percentage_error: 27.7344 - val_loss: 57.8663 - val_mean_absolute_percentage_error: 31.8070
# Epoch 42/100
# 404/404 [==============================] - 0s 59us/step - loss: 58.9317 - mean_absolute_percentage_error: 27.0202 - val_loss: 56.6529 - val_mean_absolute_percentage_error: 30.3196
# Epoch 43/100
# 404/404 [==============================] - 0s 104us/step - loss: 60.1269 - mean_absolute_percentage_error: 28.6653 - val_loss: 56.8967 - val_mean_absolute_percentage_error: 31.3190
# Epoch 44/100
# 404/404 [==============================] - 0s 64us/step - loss: 59.2785 - mean_absolute_percentage_error: 25.3615 - val_loss: 55.8739 - val_mean_absolute_percentage_error: 29.3620
# Epoch 45/100
# 404/404 [==============================] - 0s 62us/step - loss: 59.3749 - mean_absolute_percentage_error: 28.6637 - val_loss: 56.9663 - val_mean_absolute_percentage_error: 31.9544
# Epoch 46/100
# 404/404 [==============================] - 0s 62us/step - loss: 58.0954 - mean_absolute_percentage_error: 25.8618 - val_loss: 55.1799 - val_mean_absolute_percentage_error: 28.9514
# Epoch 47/100
# 404/404 [==============================] - 0s 69us/step - loss: 58.0197 - mean_absolute_percentage_error: 27.4520 - val_loss: 56.2918 - val_mean_absolute_percentage_error: 31.7394
# Epoch 48/100
# 404/404 [==============================] - 0s 69us/step - loss: 57.6124 - mean_absolute_percentage_error: 26.3040 - val_loss: 54.5481 - val_mean_absolute_percentage_error: 29.6547
# Epoch 49/100
# 404/404 [==============================] - 0s 102us/step - loss: 56.6908 - mean_absolute_percentage_error: 26.4590 - val_loss: 54.6770 - val_mean_absolute_percentage_error: 30.4350
# Epoch 50/100
# 404/404 [==============================] - 0s 94us/step - loss: 56.5739 - mean_absolute_percentage_error: 27.3863 - val_loss: 54.4339 - val_mean_absolute_percentage_error: 30.4579
# Epoch 51/100
# 404/404 [==============================] - 0s 84us/step - loss: 56.1473 - mean_absolute_percentage_error: 26.1806 - val_loss: 53.8182 - val_mean_absolute_percentage_error: 29.8232
# Epoch 52/100
# 404/404 [==============================] - 0s 87us/step - loss: 55.8020 - mean_absolute_percentage_error: 26.0466 - val_loss: 53.5519 - val_mean_absolute_percentage_error: 29.9129
# Epoch 53/100
# 404/404 [==============================] - 0s 69us/step - loss: 55.4881 - mean_absolute_percentage_error: 26.1384 - val_loss: 53.5163 - val_mean_absolute_percentage_error: 30.1792
# Epoch 54/100
# 404/404 [==============================] - 0s 72us/step - loss: 55.6955 - mean_absolute_percentage_error: 25.9254 - val_loss: 52.7555 - val_mean_absolute_percentage_error: 29.3012
# Epoch 55/100
# 404/404 [==============================] - 0s 67us/step - loss: 54.8661 - mean_absolute_percentage_error: 26.5018 - val_loss: 53.1836 - val_mean_absolute_percentage_error: 30.4373
# Epoch 56/100
# 404/404 [==============================] - 0s 69us/step - loss: 54.7918 - mean_absolute_percentage_error: 26.1855 - val_loss: 52.4271 - val_mean_absolute_percentage_error: 29.7312
# Epoch 57/100
# 404/404 [==============================] - 0s 69us/step - loss: 54.4516 - mean_absolute_percentage_error: 25.7643 - val_loss: 51.7933 - val_mean_absolute_percentage_error: 28.9349
# Epoch 58/100
# 404/404 [==============================] - 0s 64us/step - loss: 54.5204 - mean_absolute_percentage_error: 24.9534 - val_loss: 52.0452 - val_mean_absolute_percentage_error: 29.9597
# Epoch 59/100
# 404/404 [==============================] - 0s 67us/step - loss: 54.3118 - mean_absolute_percentage_error: 27.0833 - val_loss: 51.1795 - val_mean_absolute_percentage_error: 28.9995
# Epoch 60/100
# 404/404 [==============================] - 0s 62us/step - loss: 53.5070 - mean_absolute_percentage_error: 25.6096 - val_loss: 50.7247 - val_mean_absolute_percentage_error: 28.5586
# Epoch 61/100
# 404/404 [==============================] - 0s 62us/step - loss: 53.4693 - mean_absolute_percentage_error: 25.7537 - val_loss: 50.3758 - val_mean_absolute_percentage_error: 28.5016
# Epoch 62/100
# 404/404 [==============================] - 0s 67us/step - loss: 52.8608 - mean_absolute_percentage_error: 24.7906 - val_loss: 50.4519 - val_mean_absolute_percentage_error: 29.1661
# Epoch 63/100
# 404/404 [==============================] - 0s 64us/step - loss: 53.1310 - mean_absolute_percentage_error: 26.4279 - val_loss: 49.8900 - val_mean_absolute_percentage_error: 28.5176
# Epoch 64/100
# 404/404 [==============================] - 0s 67us/step - loss: 52.5004 - mean_absolute_percentage_error: 25.5440 - val_loss: 49.4576 - val_mean_absolute_percentage_error: 28.1509
# Epoch 65/100
# 404/404 [==============================] - 0s 72us/step - loss: 52.0307 - mean_absolute_percentage_error: 24.5380 - val_loss: 49.6419 - val_mean_absolute_percentage_error: 29.1361
# Epoch 66/100
# 404/404 [==============================] - 0s 62us/step - loss: 51.6570 - mean_absolute_percentage_error: 25.2796 - val_loss: 49.2388 - val_mean_absolute_percentage_error: 28.9503
# Epoch 67/100
# 404/404 [==============================] - 0s 62us/step - loss: 51.3507 - mean_absolute_percentage_error: 25.3069 - val_loss: 48.2383 - val_mean_absolute_percentage_error: 27.3824
# Epoch 68/100
# 404/404 [==============================] - 0s 67us/step - loss: 51.2765 - mean_absolute_percentage_error: 24.9743 - val_loss: 48.3302 - val_mean_absolute_percentage_error: 28.3305
# Epoch 69/100
# 404/404 [==============================] - 0s 69us/step - loss: 50.8646 - mean_absolute_percentage_error: 24.5432 - val_loss: 48.1803 - val_mean_absolute_percentage_error: 28.5774
# Epoch 70/100
# 404/404 [==============================] - 0s 64us/step - loss: 50.5695 - mean_absolute_percentage_error: 24.1297 - val_loss: 47.7541 - val_mean_absolute_percentage_error: 28.3903
# Epoch 71/100
# 404/404 [==============================] - 0s 64us/step - loss: 49.7859 - mean_absolute_percentage_error: 24.8314 - val_loss: 47.1192 - val_mean_absolute_percentage_error: 27.9457
# Epoch 72/100
# 404/404 [==============================] - 0s 62us/step - loss: 49.6488 - mean_absolute_percentage_error: 25.1672 - val_loss: 46.5845 - val_mean_absolute_percentage_error: 27.3993
# Epoch 73/100
# 404/404 [==============================] - 0s 59us/step - loss: 49.0629 - mean_absolute_percentage_error: 23.9323 - val_loss: 46.4479 - val_mean_absolute_percentage_error: 27.7453
# Epoch 74/100
# 404/404 [==============================] - 0s 69us/step - loss: 48.7324 - mean_absolute_percentage_error: 24.0614 - val_loss: 45.8337 - val_mean_absolute_percentage_error: 27.0481
# Epoch 75/100
# 404/404 [==============================] - 0s 67us/step - loss: 48.3057 - mean_absolute_percentage_error: 24.2787 - val_loss: 45.6359 - val_mean_absolute_percentage_error: 27.3191
# Epoch 76/100
# 404/404 [==============================] - 0s 64us/step - loss: 48.0498 - mean_absolute_percentage_error: 23.8614 - val_loss: 45.4771 - val_mean_absolute_percentage_error: 27.5591
# Epoch 77/100
# 404/404 [==============================] - 0s 59us/step - loss: 47.5198 - mean_absolute_percentage_error: 24.2131 - val_loss: 44.5878 - val_mean_absolute_percentage_error: 26.5643
# Epoch 78/100
# 404/404 [==============================] - 0s 62us/step - loss: 47.2579 - mean_absolute_percentage_error: 23.0049 - val_loss: 44.4863 - val_mean_absolute_percentage_error: 27.0769
# Epoch 79/100
# 404/404 [==============================] - 0s 57us/step - loss: 47.0279 - mean_absolute_percentage_error: 24.0616 - val_loss: 43.6473 - val_mean_absolute_percentage_error: 25.6340
# Epoch 80/100
# 404/404 [==============================] - 0s 77us/step - loss: 46.9562 - mean_absolute_percentage_error: 23.3933 - val_loss: 44.9399 - val_mean_absolute_percentage_error: 28.2630
# Epoch 81/100
# 404/404 [==============================] - 0s 74us/step - loss: 45.8885 - mean_absolute_percentage_error: 23.6799 - val_loss: 42.7932 - val_mean_absolute_percentage_error: 24.9758
# Epoch 82/100
# 404/404 [==============================] - 0s 89us/step - loss: 46.0057 - mean_absolute_percentage_error: 22.6868 - val_loss: 43.0689 - val_mean_absolute_percentage_error: 26.9552
# Epoch 83/100
# 404/404 [==============================] - 0s 69us/step - loss: 45.4707 - mean_absolute_percentage_error: 22.2544 - val_loss: 42.4048 - val_mean_absolute_percentage_error: 26.3946
# Epoch 84/100
# 404/404 [==============================] - 0s 64us/step - loss: 45.3771 - mean_absolute_percentage_error: 24.8516 - val_loss: 41.3723 - val_mean_absolute_percentage_error: 25.1234
# Epoch 85/100
# 404/404 [==============================] - 0s 69us/step - loss: 44.8748 - mean_absolute_percentage_error: 21.4963 - val_loss: 41.6271 - val_mean_absolute_percentage_error: 26.2537
# Epoch 86/100
# 404/404 [==============================] - 0s 62us/step - loss: 44.0220 - mean_absolute_percentage_error: 23.0497 - val_loss: 40.5413 - val_mean_absolute_percentage_error: 24.9173
# Epoch 87/100
# 404/404 [==============================] - 0s 102us/step - loss: 43.4189 - mean_absolute_percentage_error: 22.6768 - val_loss: 40.2177 - val_mean_absolute_percentage_error: 25.2874
# Epoch 88/100
# 404/404 [==============================] - 0s 94us/step - loss: 42.9963 - mean_absolute_percentage_error: 21.3398 - val_loss: 39.9538 - val_mean_absolute_percentage_error: 25.3142
# Epoch 89/100
# 404/404 [==============================] - 0s 89us/step - loss: 43.2194 - mean_absolute_percentage_error: 23.2376 - val_loss: 38.9838 - val_mean_absolute_percentage_error: 23.7698
# Epoch 90/100
# 404/404 [==============================] - 0s 92us/step - loss: 42.1904 - mean_absolute_percentage_error: 21.4012 - val_loss: 39.8564 - val_mean_absolute_percentage_error: 26.1442
# Epoch 91/100
# 404/404 [==============================] - 0s 74us/step - loss: 41.2662 - mean_absolute_percentage_error: 22.0601 - val_loss: 38.0598 - val_mean_absolute_percentage_error: 23.8070
# Epoch 92/100
# 404/404 [==============================] - 0s 69us/step - loss: 40.9640 - mean_absolute_percentage_error: 21.5611 - val_loss: 38.2722 - val_mean_absolute_percentage_error: 25.1224
# Epoch 93/100
# 404/404 [==============================] - 0s 59us/step - loss: 40.3254 - mean_absolute_percentage_error: 21.2858 - val_loss: 37.0722 - val_mean_absolute_percentage_error: 23.5958
# Epoch 94/100
# 404/404 [==============================] - 0s 54us/step - loss: 40.3146 - mean_absolute_percentage_error: 21.5682 - val_loss: 36.5312 - val_mean_absolute_percentage_error: 22.8767
# Epoch 95/100
# 404/404 [==============================] - 0s 111us/step - loss: 39.2563 - mean_absolute_percentage_error: 20.8745 - val_loss: 36.8244 - val_mean_absolute_percentage_error: 24.5506
# Epoch 96/100
# 404/404 [==============================] - 0s 97us/step - loss: 39.3789 - mean_absolute_percentage_error: 22.4429 - val_loss: 35.6066 - val_mean_absolute_percentage_error: 21.9032
# Epoch 97/100
# 404/404 [==============================] - 0s 57us/step - loss: 39.8683 - mean_absolute_percentage_error: 19.6700 - val_loss: 36.7766 - val_mean_absolute_percentage_error: 25.2319
# Epoch 98/100
# 404/404 [==============================] - 0s 52us/step - loss: 38.0640 - mean_absolute_percentage_error: 22.1316 - val_loss: 34.8959 - val_mean_absolute_percentage_error: 21.2614
# Epoch 99/100
# 404/404 [==============================] - 0s 69us/step - loss: 38.6656 - mean_absolute_percentage_error: 19.4405 - val_loss: 36.9799 - val_mean_absolute_percentage_error: 25.9112
# Epoch 100/100
# 404/404 [==============================] - 0s 79us/step - loss: 37.7649 - mean_absolute_percentage_error: 21.0145 - val_loss: 33.7813 - val_mean_absolute_percentage_error: 21.9791

# %%
results = model.evaluate(x_test, y_test)

for i in range(len(model.metrics_names)):
  print(model.metrics_names[i]," : ", results[i])
# Out:
# 102/102 [==============================] - 0s 108us/step
# loss  :  37.03384922999962
# mean_absolute_percentage_error  :  17.74384307861328

# %%
import matplotlib.pyplot as plt

history = model.fit(x_train, y_train, batch_size=32, epochs=200,validation_data=(x_val,y_val), verbose=0)  #verbose para que no muestre toda la info anterior 
# Plot training & validation accuracy values
plt.figure(figsize=(13,6))
plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model mean_absolute_percentage_error')
plt.ylabel('MAPE %')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show();

# Plot training & validation loss values
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show();

# %% [markdown]
# **Happy Coding!**
